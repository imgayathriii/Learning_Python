# %%
A = { "a","b","c","d","e"}
print(A)
# Out:
# {'c', 'b', 'd', 'a', 'e'}

# %%
A[1] = "f"
print(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2907662697.py in <cell line: 0>()
# ----> 1 A[1] = "f"
#       2 print(A)
#
# TypeError: 'set' object does not support item assignment

# %%
m = ("a","b","c","d","e")
print(m)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
m[1] = "g"
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3847571043.py in <cell line: 0>()
# ----> 1 m[1] = "g"
#       2 print(m)
#
# TypeError: 'tuple' object does not support item assignment

# %%
empty_tuple = ()
print()

# %%
numbers = (1,2,3,4)
print(numbers)
# Out:
# (1, 2, 3, 4)

# %%
mixed = (1, "hello",3.5,True)
print(mixed)
# Out:
# (1, 'hello', 3.5, True)

# %%
Ex = 10,20,30
print(Ex)
# Out:
# (10, 20, 30)

# %%
single = (5,)
print(single)
# Out:
# (5,)

# %%
fruits = ("Apple","Banana","Cherry")
print(fruits[0])
# Out:
# Apple

# %%
fruits = ("Apple","Banana","Cherry")
print(fruits[2])
# Out:
# Cherry

# %%
fruits = ("Apple","Banana","Cherry")
print(fruits[-1])
# Out:
# Cherry

# %%
numbers = (10,20,30,40,50)
print(numbers)
# Out:
# (10, 20, 30, 40, 50)

# %%
numbers = (10,20,30,40,50)
print(numbers[1:4])
# Out:
# (20, 30, 40)

# %%
numbers = (10,20,30,40,50)
print(numbers[::2])
# Out:
# (10, 30, 50)

# %%
fruits = ("Apple","Banana","Cherry")
fruits[1] = "Orange"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3143349900.py in <cell line: 0>()
#       1 fruits = ("Apple","Banana","Cherry")
# ----> 2 fruits[1] = "Orange"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = (1,2)
b = (3,4)
print (a +  b)
# Out:
# (1, 2, 3, 4)

# %%
a = (1,2)
b = (3,4)
print(a*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
a = (1,2)
b = (3,4)
print (2 in a)
# Out:
# True

# %%
a = (1,2)
b = (3,4)
print(5 not in a)
# Out:
# True

# %%
a = (1,2)
b = (3,4)
print(5 in a)
# Out:
# False

# %%
numbers = (1,2,2,3,4)
print(numbers.count(2))
# Out:
# 2

# %%
numbers = (1,2,2,3,4)
print(numbers.index(3))
# Out:
# 3

# %%
#Packing
person = ("John", 25, "Engineer")
#unpacking
name,age,job = person
print(name)
print(age)
print(job)
# Out:
# John
# 25
# Engineer

# %%
nested = ((1,2),(3,4),(5,6))
print(nested[1])
# Out:
# (3, 4)

# %%
nested =  ((1,2),(3,4),(5,6))
print(nested[1],[0])
# Out:
# (3, 4) [0]

# %%
coordinates = (10,20)
print(coordinates[0])
# Out:
# 10

# %%
fruits = ['apple','banana','cherry']
fruits.append('orange')
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
empty_set = set()
print(empty_set)
# Out:
# set()

# %%
numbers = {1,2,3,4}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
mixed = {1,"hello",3.5,False}
print(mixed)
# Out:
# {'hello', 1, 3.5, False}

# %%
mixed = {1,"hello",3.5,True}
print(mixed)
# Out:
# {'hello', 1, 3.5}

# %%
From_list = set([1,2,2,3,4])
print(From_list)
# Out:
# {1, 2, 3, 4}

# %%
fruits = {'apple','banana'}
for f in fruits:
  print(f)
# Out:
# banana
# apple

# %%
fruits = {'apple','banana'}
fruits.add('cherry')
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
fruits ={'apple','banana'}
fruits.update(['orange','grape'])
print(fruits)
# Out:
# {'grape', 'banana', 'orange', 'apple'}

# %%
fruits.remove('banana')
print(fruits)
# Out:
# {'grape', 'orange', 'apple'}

# %%
fruits.discard('pineapple')
print(fruits)
# Out:
# {'grape', 'orange', 'apple'}

# %%
fruits.pop()
print(fruits)
# Out:
# {'orange', 'apple'}

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a|b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a & b)
# Out:
# {3, 4}

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a - b)
print(b - a)
# Out:
# {1, 2}
# {5, 6}

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a^b)
# Out:
# {1, 2, 5, 6}

# %%
a = {1,2,3}
copy_set = numbers.copy()
print(a)
# Out:
# {1, 2, 3}

# %%
a = {1,2,3}
numbers.clear()
print(a)
# Out:
# {1, 2, 3}

# %%
a = {1,2,3}
print(len(copy_set))
# Out:
# 4

# %%
a = {1,2,3}
print(2 in copy_set)
# Out:
# True

# %%
frozen = frozenset([1,2,3,3])
print(frozen)
# Out:
# frozenset({1, 2, 3})

# %%
empty_dict = ()
print(empty_dict)
# Out:
# ()

# %%
student = {"name":"Alice","age":21,"course":"python"}
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'course': 'python'}

# %%
person = dict(name="john",age=30,job="engineer")
print(person)
# Out:
# {'name': 'john', 'age': 30, 'job': 'engineer'}

# %%
student = {"name":"alice","age":21}
print(student)
# Out:
# {'name': 'alice', 'age': 21}

# %%
student = {"name":"alice","age":21}
print(student["name"])
# Out:
# alice

# %%
student = {"name":"alice","age":21}
print(student.get("name","not found"))
# Out:
# alice

# %%
student = {"name":"Alice","age":21}
student["course"]="python"
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'course': 'python'}

# %%
student["age"]=22
print(student)
# Out:
# {'name': 'Alice', 'age': 22, 'course': 'python'}

# %%
student = {"name":"Alice","age":21,"course":"python"}
student.pop("age")
# Out:
# 21

# %%
student.popitem()
print(student)
# Out:
# {'name': 'Alice'}

# %%
student.clear()
print(student)
# Out:
# {}

# %%
student = {"name":"Alice","age":21}
print (student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
student = {"name":"Alice","age":21}
print (student.values())
# Out:
# dict_values(['Alice', 21])

# %%
student = {"name":"Alice","age":21}
print (student.items())
# Out:
# dict_items([('name', 'Alice'), ('age', 21)])

# %%
copy_dict = student.copy()
print(copy_dict)
# Out:
# {'name': 'Alice', 'age': 21}

# %%
student = {"name":"Alice","age":21,"course":"python"}
for key in student:
  print (key)
# Out:
# name
# age
# course

# %%
student = {"name":"Alice","age":21,"course":"pyhton)"}
for value in student.values():
  print(value)
# Out:
# Alice
# 21
# pyhton)

# %%
for key, value in student.items():
  print(key,":", value)
# Out:
# name : Alice
# age : 21
# course : pyhton)

# %%
students = { "student1":{"Name":"Alice","Age":21},
            "student2":{"Name":"Bob","Age":22}
           }
print(students["student1"]["Name"])
# Out:
# Alice

# %%
print(students["student2"]["Age"])
# Out:
# 22

# %%
0
