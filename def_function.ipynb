# %%
def add():
  a = int(input())
  b = int(input())
  print(a  + b)
add()
add()
add()
add()
add()
# Out:
# 5
# 7
# 12
# 9
# 8
# 17
# 12
# 55
# 67
# 10
# 7
# 17
# 45
# 21
# 66

# %%
for i in range (0,3):
  add()
# Out:
# 4
# 9
# 13
# 8
# 98
# 106
# 25
# 12
# 37

# %%
# create a function to print yable of 10.
def table():
  count = 1
  for i in range(10,101,10):
    print(f"10 x {count} = {i}")
    count = count + 1

# %%
table()
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %%
#crate a fudef square ():
a = int(input())
print(a*a)

square()
# Out:
# 4
# 16

# %%
def square():
  a = int(input())
  print

# %%
def circle ():
  a = int(input())
  print(3.14*3.14)
circle ()
# Out:
# 6
# 9.8596

# %%
def rectangle ():
  a = int(input())
  b = int(input())
  print(a*b)
rectangle ()
rectangle()
rectangle()
# Out:
# 5
# 9
# 45
# 8
# 2
# 16
# 7
# 6
# 42

# %%
def rectangle (a,b):
  print(a*b)
a = int(input())
b = int(input())
rectangle(a,b)
rectangle(a,b)
rectangle(a,b)
# Out:
# 8
# 9
# 72
# 72
# 72

# %%
def count ():
  a = [1,3,5,3,4,3,2,3,4,5,3,1]
  print(a.count(3))
count ()
# Out:
# 5

# %%
a = int(input())
print(a)
# Out:
# 6
# 6

# %%
def table(b) :
  count = 1
  for i in range (b,b*10+1,b):
    print(f"{b} x {count} = {i}")
    count = count + 1
a = int(input('Enter a number'))
table(a)
# Out:
# Enter a number9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
def count ():
  a = [1,3,5,3,4,3,2,3,4,5,3,1]
  return a.count(3)

print(count())
# Out:
# 5

# %%
a = []
n = int(input('Enter number of item you want to enter:'))
for i in range(0,n):
  f = input()
  a.append(f)
print(i)
# Out:
# Enter number of item you want to enter:2
# hghgh
# jhjhj
# 1

# %%
print(a)
# Out:
# ['apple', 'banana', 'cherry', 'kivi']

# %%
flowers = []
a = int(input('enter number of item you want to enter:'))
for i in range(0,a):
  f = input()
  flowers.append(f)
# Out:
# enter number of item you want to enter:3
# rose
# lily
# lotus

# %%
print(flowers)
# Out:
# ['rose', 'lily', 'lotus']

# %%
'''def appen():
  flowers.append('Mogra')
  return flowers'''

def remove():
  flowers.remove('lily')
  return flowers

def index():
  m = flowers.index('rose')
  return m
#print(appen())
print(remove())
print(index())
# Out:
# ['rose', 'lotus', 'Mogra']
# 0
