# %%
# Addition
a = 10
b = 5
print(a+b)
# Out:
# 15

# %%
# subtraction
a = 10
b = 5
print(a-b)
# Out:
# 5

# %%
# multiplication
a = 10
b = 5
print(a*b)
# Out:
# 50

# %%
# Division
a = 10
b = 5
print(a/b)
# Out:
# 2.0

# %%
# floor division
a = 10
b = 5
print(a//b)
# Out:
# 2

# %%
# Modulus
a = 10
b = 5
print(a%b)
# Out:
# 0

# %%
# Exponentiation
a = 10
b = 5
print(a**b)
# Out:
# 100000

# %%
# Comparison operator
# Equal
X = 5
Y = 10
print(X==Y)
# Out:
# False

# %%
# Not Equal
X = 5
Y = 10
print(X!=Y)
# Out:
# True

# %%
# Greater than
X = 5
Y = 10
print(X > Y)
# Out:
# False

# %%
# Less than
X = 5
Y = 10
print(X < Y)
# Out:
# True

# %%
# Greater or Equal
X = 5
Y = 10
print(X >= Y)
# Out:
# False

# %%
# Less or Equal
X = 5
Y = 10
print(X <= Y)
# Out:
# True

# %%
#Logical operators
a = True
b = False
print(a and b)
# Out:
# False

# %%
a = True
b = False
print(a or b)
# Out:
# True

# %%
a = True
b = False
print(not b)
# Out:
# True

# %%
# Assignment operators
# Simple assignment
X = 5
print(X)
# Out:
# 5

# %%
X += 3
print(X)
# Out:
# 8

# %%
X -= 3
print(X)
# Out:
# 5

# %%
X *= 4
print(X)
# Out:
# 60

# %%
X /=6
print(X)
# Out:
# 10.0

# %%
X %= 3
print(X)
# Out:
# 1.0

# %%
X ** 2
print(X)
# Out:
# 1.0

# %%
# Bitwise operator
a = 6
b = 3
print(a&b)
# Out:
# 2
# 7
# 5

# %%
a = 6
b = 3
print(a|b)
# Out:
# 7

# %%
a = 6
b = 3
print(a^b)
# Out:
# 5

# %%
a = 6
b = 3
print(~a)
# Out:
# -7

# %%
a = 6
b = 3
print(~b)
# Out:
# -4

# %%
a = 6
b = 3
print(a<<b)
# Out:
# 48

# %%
a = 6
b = 3
print(a>>b)
# Out:
# 0
